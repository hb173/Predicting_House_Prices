# %% [markdown]
# # Train Final Models Using LightGBM
# After comparing the performance of different models fitted by the team, we decided to use LightGBM for our final models.
# The code below trains 3 models, each with its own hyperparameter values:
# 1. LGBM trained on all data
# 2. LGBM trained on CA data only
# 3. LGBM trained on GA data only

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer
from sklearn.compose import make_column_transformer
from sklearn.compose import make_column_selector
from sklearn.decomposition import PCA
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score as auc
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as rmse_score

from scipy.stats import randint
from scipy.stats import loguniform
from scipy.stats import uniform

from xgboost.sklearn import XGBRegressor
from lightgbm.sklearn import LGBMRegressor

from hyperopt import tpe, hp, fmin, STATUS_OK,Trials
from hyperopt.pyll.base import scope
from hyperopt.pyll.stochastic import sample

# %% [markdown]
# ### Code to save and load models

# %%
# save models to local drive
import pickle

def save_obj(obj, filename):
    try:
        with open(filename, "wb") as f:
            pickle.dump(obj, f, protocol=pickle.HIGHEST_PROTOCOL)
    except Exception as ex:
        print("Error:", ex)


def load_obj(filename):
    try:
        with open(filename, "rb") as f:
            return pickle.load(f)
    except Exception as ex:
        print("Error:", ex)

# %% [markdown]
# ## Train LBGM on updated data - All Data

# %%
# load data and clean
X_train = pd.read_csv('../large_data_files/Train and Valid Data for model comparison/X_train_model2.csv')
y_train = pd.read_csv('../large_data_files/Train and Valid Data for model comparison/y_train_model2.csv')
X_validate = pd.read_csv('../large_data_files/Train and Valid Data for model comparison/X_valid_model2.csv')
y_validate = pd.read_csv('../large_data_files/Train and Valid Data for model comparison/y_valid_model2.csv')

X_train_all = pd.read_csv('../large_data_files/All Data/X_train_all.csv')
y_train_all = pd.read_csv('../large_data_files/All Data/y_train_all.csv')
X_test = pd.read_csv('../large_data_files/All Data/X_test_all.csv')
y_test = pd.read_csv('../large_data_files/All Data/y_test_all.csv')


X_train.drop(columns=['Unnamed: 0'], inplace=True)
y_train.drop(columns=['Unnamed: 0'], inplace=True)
X_validate.drop(columns=['Unnamed: 0'], inplace=True)
y_validate.drop(columns=['Unnamed: 0'], inplace=True)

X_train_all.drop(columns=['Unnamed: 0'], inplace=True)
y_train_all.drop(columns=['Unnamed: 0'], inplace=True)
X_test.drop(columns=['Unnamed: 0'], inplace=True)
y_test.drop(columns=['Unnamed: 0'], inplace=True)


# rename this column which gives an error in LGBM because its name has quotation marks
X_train.rename(columns={'city_"oneals"': 'city_oneals'}, inplace=True)
X_validate.rename(columns={'city_"oneals"': 'city_oneals'}, inplace=True)

X_train_all.rename(columns={'city_"oneals"': 'city_oneals'}, inplace=True)
X_test.rename(columns={'city_"oneals"': 'city_oneals'}, inplace=True)

# %%
# use hyperopt to tune hyperparameter values
space = {
    'boosting': 'dart',
    'n_estimators': scope.int(hp.quniform('n_estimators', 255,290,3)),
    'num_leaves': scope.int(hp.quniform("num_leaves", 140, 170, 2)),
    'max_depth': scope.int(hp.quniform("max_depth", 0, 4, 1)),
    'learning_rate': hp.loguniform('learning_rate', -1.3, 0),
    'min_data_in_leaf': scope.int(hp.quniform('min_data_in_leaf', 0, 4, 1)),
    'feature_fraction': hp.uniform('feature_fraction', 0.73, 0.83),
    'bagging_fraction': hp.uniform('bagging_fraction', 0.5, 0.6),
    'lambda_l1': hp.choice('lambda_l1', [0, hp.loguniform('lambda_l1_value', -10, -6)]),
    'lambda_l2': hp.choice('lambda_l2', [0, hp.loguniform('lambda_l2_value', -4, -2.5)]),
    'min_child_weight': hp.loguniform('min_child_weight', -12, -10),
}

def lgbm_tuning(params):
    clf=LGBMRegressor(**params)
    clf.fit(X_train, y_train)
    rmse = (rmse_score(y_true=y_validate, y_pred=clf.predict(X_validate)))**0.5
    print("RMSE:", rmse)
    return {'loss': rmse, 'status': STATUS_OK}

trials = Trials()

# %%
best = fmin(
    fn=lgbm_tuning,
    space = space,
    algo=tpe.suggest,
    max_evals=150,
    trials=trials
)

# %%
best
# Out:
# {'bagging_fraction': 0.552936314269197,
#  'feature_fraction': 0.7733644348291246,
#  'lambda_l1': 0,
#  'lambda_l2': 1,
#  'lambda_l2_value': 0.05349775487562866,
#  'learning_rate': 0.5567627566029032,
#  'max_depth': 2.0,
#  'min_child_weight': 2.607851332618328e-05,
#  'min_data_in_leaf': 2.0,
#  'n_estimators': 260.0,
#  'num_leaves': 160.0}

# %%
# fit on all training data
lgbm_all_data = LGBMRegressor(
    boosting='DART',
    bagging_fraction=best['bagging_fraction'], 
    feature_fraction=best['feature_fraction'],
    reg_alpha=0,
    reg_lambda=best['lambda_l2_value'],
    max_depth=int(best['max_depth']),
    min_child_weight=best['min_child_weight'],
    min_data_in_leaf=int(best['min_data_in_leaf']),
    n_estimators=int(best['n_estimators']),
    num_leaves=int(best['num_leaves']),
    learning_rate=best['learning_rate'],
)
lgbm_all_data.fit(X_train_all, y_train_all)
r2_score(y_test,lgbm_all_data.predict(X_test))
# Out:
# [LightGBM] [Warning] boosting is set=DART, boosting_type=gbdt will be ignored. Current value: boosting=DART
# [LightGBM] [Warning] feature_fraction is set=0.7740280408904768, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7740280408904768
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] bagging_fraction is set=0.5331527261694778, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5331527261694778
# 0.5475287443196867

# %%
# save model
save_obj(lgbm_all_data, '../models/lgbm_all_data.pickle')

# %% [markdown]
# ## Train on GA data only

# %%
# laod data and clean
# training data
X_train_GA = pd.read_csv('../large_data_files/GA Data/X_train_GA.csv')
y_train_GA = pd.read_csv('../large_data_files/GA Data/y_train_GA.csv')

X_train_GA = X_train_GA[X_train_GA.columns.drop(list(X_train_GA.filter(regex='state_')))]
X_train_GA = X_train_GA[X_train_GA.columns.drop(list(X_train_GA.filter(regex='city_')))]
X_train_GA = X_train_GA[X_train_GA.columns.drop(list(X_train_GA.filter(regex='county_')))]

X_train_GA.drop(columns=['Unnamed: 0'], inplace=True)
y_train_GA.drop(columns=['Unnamed: 0'], inplace=True)

X_train_GA.rename(columns={'city_"oneals"': 'city_oneals'}, inplace=True)

# test data
X_test_GA = pd.read_csv('../large_data_files/GA Data/X_test_GA.csv')
y_test_GA = pd.read_csv('../large_data_files/GA Data/y_test_GA.csv')

X_test_GA = X_test_GA[X_test_GA.columns.drop(list(X_test_GA.filter(regex='state_')))]
X_test_GA = X_test_GA[X_test_GA.columns.drop(list(X_test_GA.filter(regex='city_')))]
X_test_GA = X_test_GA[X_test_GA.columns.drop(list(X_test_GA.filter(regex='county_')))]

X_test_GA.drop(columns=['Unnamed: 0'], inplace=True)
y_test_GA.drop(columns=['Unnamed: 0'], inplace=True)

X_test_GA.rename(columns={'city_"oneals"': 'city_oneals'}, inplace=True)

# %%
# train validate split
X_train_GA_train, X_validate_GA, y_train_GA_train, y_validate_GA = train_test_split(X_train_GA, y_train_GA, train_size=0.7, random_state=42)

# %%
# use hyperopt to tune hyperparameters
space = {
    'boosting': 'dart',
    'n_estimators': scope.int(hp.quniform('n_estimators', 235,265,3)),
    'num_leaves': scope.int(hp.quniform("num_leaves", 195, 215, 3)),
    'max_depth': scope.int(hp.quniform("max_depth", 2, 6, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3.5, -0.5),
    'min_data_in_leaf': scope.int(hp.quniform('min_data_in_leaf', 0, 4, 1)),
    'feature_fraction': hp.uniform('feature_fraction', 0.70, 0.77),
    'bagging_fraction': hp.uniform('bagging_fraction', 0.62, 0.68),
    'lambda_l1': hp.choice('lambda_l1', [0]),
    'lambda_l2': hp.choice('lambda_l2', [0, hp.loguniform('lambda_l2_value', -7, -5.5)]),
    'min_child_weight': hp.loguniform('min_child_weight', -9.5, -7.5),
}

def lgbm_tuning(params):
    clf=LGBMRegressor(**params)
    clf.fit(X_train_GA_train, y_train_GA_train)
    rmse = (rmse_score(y_true=y_validate_GA, y_pred=clf.predict(X_validate_GA)))**0.5
    print("RMSE:", rmse)
    return {'loss': rmse, 'status': STATUS_OK}

trials = Trials()

best = fmin(
    fn=lgbm_tuning,
    space = space,
    algo=tpe.suggest,
    max_evals=150,
    trials=trials
)

# %%
best
# Out:
# {'bagging_fraction': 0.655632696730533,
#  'feature_fraction': 0.7665910276504753,
#  'lambda_l1': 0,
#  'lambda_l2': 1,
#  'lambda_l2_value': 0.002716867464021161,
#  'learning_rate': 0.44406926645007505,
#  'max_depth': 2.0,
#  'min_child_weight': 9.559323995283971e-05,
#  'min_data_in_leaf': 0.0,
#  'n_estimators': 252.0,
#  'num_leaves': 210.0}

# %%
# fit on all GA training data
lgbm_using_GA = LGBMRegressor(
    boosting='DART',
    bagging_fraction=best['bagging_fraction'], 
    feature_fraction=best['feature_fraction'],
    reg_alpha=0,
    reg_lambda=best['lambda_l2_value'],
    max_depth=int(best['max_depth']),
    min_child_weight=best['min_child_weight'],
    min_data_in_leaf=int(best['min_data_in_leaf']),
    n_estimators=int(best['n_estimators']),
    num_leaves=int(best['num_leaves']),
    learning_rate=best['learning_rate'],
)
lgbm_using_GA.fit(X_train_GA, y_train_GA)
r2_score(y_test_GA,lgbm_using_GA.predict(X_test_GA))
# Out:
# [LightGBM] [Warning] boosting is set=DART, boosting_type=gbdt will be ignored. Current value: boosting=DART
# [LightGBM] [Warning] feature_fraction is set=0.7665910276504753, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7665910276504753
# [LightGBM] [Warning] min_data_in_leaf is set=0, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=0
# [LightGBM] [Warning] bagging_fraction is set=0.655632696730533, subsample=1.0 will be ignored. Current value: bagging_fraction=0.655632696730533
# 0.5433452719912426

# %%
# save model
save_obj(lgbm_using_GA, '../models/lgbm_using_GA.pickle')

# %% [markdown]
# ## Train on CA data only

# %%
# load data and clean
# training data
X_train_CA = pd.read_csv('../large_data_files/CA Data/X_train_CA.csv')
y_train_CA = pd.read_csv('../large_data_files/CA Data/y_train_CA.csv')

X_train_CA = X_train_CA[X_train_CA.columns.drop(list(X_train_CA.filter(regex='state_')))]
X_train_CA = X_train_CA[X_train_CA.columns.drop(list(X_train_CA.filter(regex='city_')))]
X_train_CA = X_train_CA[X_train_CA.columns.drop(list(X_train_CA.filter(regex='county_')))]

X_train_CA.drop(columns=['Unnamed: 0'], inplace=True)
y_train_CA.drop(columns=['Unnamed: 0'], inplace=True)

X_train_CA.rename(columns={'city_"oneals"': 'city_oneals'}, inplace=True)

# test data
X_test_CA = pd.read_csv('../large_data_files/CA Data/X_test_CA.csv')
y_test_CA = pd.read_csv('../large_data_files/CA Data/y_test_CA.csv')

X_test_CA = X_test_CA[X_test_CA.columns.drop(list(X_test_CA.filter(regex='state_')))]
X_test_CA = X_test_CA[X_test_CA.columns.drop(list(X_test_CA.filter(regex='city_')))]
X_test_CA = X_test_CA[X_test_CA.columns.drop(list(X_test_CA.filter(regex='county_')))]

X_test_CA.drop(columns=['Unnamed: 0'], inplace=True)
y_test_CA.drop(columns=['Unnamed: 0'], inplace=True)

X_test_CA.rename(columns={'city_"oneals"': 'city_oneals'}, inplace=True)

# %%
# train validate split
X_train_CA_train, X_validate_CA, y_train_CA_train, y_validate_CA = train_test_split(X_train_CA, y_train_CA, train_size=0.7, random_state=42)

# %%
# use hyperopt to tune hyperparameters
space = {
    'boosting': 'dart',
    'n_estimators': scope.int(hp.quniform('n_estimators', 130,170,2)),
    'num_leaves': scope.int(hp.quniform("num_leaves", 250, 275, 2)),
    'max_depth': scope.int(hp.quniform("max_depth", 2, 7, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'min_data_in_leaf': scope.int(hp.quniform('min_data_in_leaf', 2, 6, 1)),
    'feature_fraction': hp.uniform('feature_fraction', 0.55, 0.75),
    'bagging_fraction': hp.uniform('bagging_fraction', 0.55, 0.75),
    'lambda_l1': hp.choice('lambda_l1', [0]),
    'lambda_l2': hp.choice('lambda_l2', [0]),
    'min_child_weight': hp.loguniform('min_child_weight', -8, -4),
}

def lgbm_tuning(params):
    clf=LGBMRegressor(**params)
    clf.fit(X_train_CA_train, y_train_CA_train)
    rmse = (rmse_score(y_true=y_validate_CA, y_pred=clf.predict(X_validate_CA)))**0.5
    print("RMSE:", rmse)
    return {'loss': rmse, 'status': STATUS_OK}

trials = Trials()

best = fmin(
    fn=lgbm_tuning,
    space = space,
    algo=tpe.suggest,
    max_evals=250,
    trials=trials
)
# Out:
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.736299500432098, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.736299500432098
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.7065598674521442, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7065598674521442
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1435272.1712212753
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6183641492212906, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6183641492212906
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6704486362445804, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6704486362445804
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1432459.8467993482
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7071744972542781, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7071744972542781
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6278866906256829, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6278866906256829
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1523669.7827525772
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7223175245652277, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7223175245652277
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6934200909803052, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6934200909803052
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1548727.0982058162
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6454327334125053, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6454327334125053
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.7425162323520086, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7425162323520086
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1474096.6967393067
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7284776102596194, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7284776102596194
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6159473400023351, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6159473400023351
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1506450.5410535256
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.726430441346005, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.726430441346005
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.7121618810551463, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7121618810551463
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1607712.428866077
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.5591818092570653, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5591818092570653
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5975040877714317, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5975040877714317
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1466469.3836133543
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.5777749723180147, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5777749723180147
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6977010223294804, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6977010223294804
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1528266.3688537357
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6247485560238853, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6247485560238853
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6506809812783373, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6506809812783373
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1439201.4115478147
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6028619619877663, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6028619619877663
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5659219486727733, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5659219486727733
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1451214.9792853715
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6877435746254925, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6877435746254925
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.562599998653892, subsample=1.0 will be ignored. Current value: bagging_fraction=0.562599998653892
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1551340.243926862
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6157243825958976, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6157243825958976
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6859717173457636, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6859717173457636
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1431569.4621575589
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.5621746120988168, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5621746120988168
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6486240597129033, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6486240597129033
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1504944.0934102733
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6441225395577583, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6441225395577583
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6792266316376526, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6792266316376526
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1510918.8468761046
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6098738584002793, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6098738584002793
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.7382768774077683, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7382768774077683
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1514904.8125248328
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6274321849772294, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6274321849772294
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6823298680036411, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6823298680036411
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1411474.3331717479
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7248514391178839, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7248514391178839
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.7299154412184006, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7299154412184006
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1417240.537267562
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.695768736446674, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.695768736446674
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.7490690048395525, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7490690048395525
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1397388.8673244528
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7408689810078575, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7408689810078575
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6549403253940006, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6549403253940006
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1406281.1687938399
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6794898013230486, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6794898013230486
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5923072724568896, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5923072724568896
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1423781.2288854814
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6777805218166394, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6777805218166394
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.7210260314098614, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7210260314098614
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1474949.117010952
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7489861467930773, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7489861467930773
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6489837068290689, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6489837068290689
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1488847.5605205197
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6956450441117951, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6956450441117951
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5806355830500778, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5806355830500778
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1363635.3843579353
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6986546492861576, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6986546492861576
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5511148335596882, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5511148335596882
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1455347.7385986957
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6621406008920753, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6621406008920753
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5881119239446451, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5881119239446451
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1397192.682757051
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6701532925623687, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6701532925623687
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5855539583835243, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5855539583835243
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1406688.3046378423
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6630950764737753, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6630950764737753
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6148407863937773, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6148407863937773
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1400204.8874361706
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7102733865246297, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7102733865246297
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5765177722561725, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5765177722561725
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1475955.6881336619
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6567987639200489, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6567987639200489
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5516788342136946, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5516788342136946
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1440020.0950672263
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.5932783918035827, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5932783918035827
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6070666145334097, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6070666145334097
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1519790.0566949341
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6329389777094652, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6329389777094652
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6272397638533858, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6272397638533858
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1414951.9063366824
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7099949267475925, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7099949267475925
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5740885456772917, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5740885456772917
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1413202.2458541386
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6487343317185144, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6487343317185144
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.631681365821129, subsample=1.0 will be ignored. Current value: bagging_fraction=0.631681365821129
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1426764.2941839017
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.639387338101554, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.639387338101554
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.602114633517833, subsample=1.0 will be ignored. Current value: bagging_fraction=0.602114633517833
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1693471.7716792442
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6637291220152352, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6637291220152352
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6359806657145596, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6359806657145596
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1434771.545348187
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6887493796503398, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6887493796503398
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5835720384820563, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5835720384820563
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1406581.2581004305
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7391159788624979, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7391159788624979
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.560856510118269, subsample=1.0 will be ignored. Current value: bagging_fraction=0.560856510118269
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1420448.025262835
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7163477113461628, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7163477113461628
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6163609403779938, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6163609403779938
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1411931.070955048
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6990579846609914, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6990579846609914
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6679566863747093, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6679566863747093
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1459075.676117491
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6757387187808329, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6757387187808329
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5710111095037311, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5710111095037311
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1540658.8396351675
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.5957505257611416, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5957505257611416
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5916982309411408, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5916982309411408
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1423729.1626246565
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7489768065387429, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7489768065387429
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5562436350962866, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5562436350962866
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1451738.7667576505
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6534196498586814, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6534196498586814
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6067906134891137, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6067906134891137
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1450955.501141444
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6868091164309585, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6868091164309585
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6223220634977631, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6223220634977631
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1509865.8525530307
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.5752534074855041, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5752534074855041
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6580300283940875, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6580300283940875
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1420869.9217193716
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7314589206750528, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7314589206750528
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6394499253615623, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6394499253615623
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1436033.929181258
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6332035727196761, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6332035727196761
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5809924531162237, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5809924531162237
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1380100.5864624057
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6147232226289381, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6147232226289381
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5807966138725765, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5807966138725765
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1438852.9365337656
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6379616512026186, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6379616512026186
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.7000454772029162, subsample=1.0 will be ignored. Current value: bagging_fraction=0.7000454772029162
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1417725.245664389
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6237456236463798, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6237456236463798
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5966500888336174, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5966500888336174
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1423853.8285165199
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6055915355844815, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6055915355844815
# [LightGBM] [Warning] min_data_in_leaf is set=2, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=2
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5625231266512161, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5625231266512161
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1530759.588583451
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.5856171035188418, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5856171035188418
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.670956363808201, subsample=1.0 will be ignored. Current value: bagging_fraction=0.670956363808201
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1451802.6439720388
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.5604036413733832, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5604036413733832
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6419627036062481, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6419627036062481
# ...
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6132910472854831, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6132910472854831
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1426810.923708398
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6104721144444359, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6104721144444359
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6075788465148558, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6075788465148558
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1478015.7435620711
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.5785380816611769, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5785380816611769
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.588338722174243, subsample=1.0 will be ignored. Current value: bagging_fraction=0.588338722174243
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1442528.5570555585
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.691404650309648, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.691404650309648
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.593498622693717, subsample=1.0 will be ignored. Current value: bagging_fraction=0.593498622693717
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1396197.61644764
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6717893594823615, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6717893594823615
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.555017312861345, subsample=1.0 will be ignored. Current value: bagging_fraction=0.555017312861345
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1434544.513560333
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.5655609820372172, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5655609820372172
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5793280566633898, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5793280566633898
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1499122.7340824995
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7115055090951693, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7115055090951693
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5956753387330171, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5956753387330171
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1504548.587155019
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7412735059000671, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7412735059000671
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5618249323172427, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5618249323172427
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1481173.6294710415
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6548269489256567, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6548269489256567
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.567927264154864, subsample=1.0 will be ignored. Current value: bagging_fraction=0.567927264154864
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1428918.8394667176
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.5909354283208454, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.5909354283208454
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6197147848545043, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6197147848545043
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1527476.7470213505
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6635406648054656, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6635406648054656
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5503247899052155, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5503247899052155
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1421973.6566160102
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.7200376754022259, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.7200376754022259
# [LightGBM] [Warning] min_data_in_leaf is set=6, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=6
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6358532729399734, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6358532729399734
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1447310.2709396211
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6510648647301401, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6510648647301401
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6286888221104575, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6286888221104575
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1439699.0698401355
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6977024333342771, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6977024333342771
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6459283224343745, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6459283224343745
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1426346.0001724276
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6175495058197281, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6175495058197281
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.600353612315078, subsample=1.0 will be ignored. Current value: bagging_fraction=0.600353612315078
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1381208.907739344
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6872182023238329, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6872182023238329
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5739114884592447, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5739114884592447
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1438350.9516615737
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.630997666595001, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.630997666595001
# [LightGBM] [Warning] min_data_in_leaf is set=3, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=3
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.5805541854274187, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5805541854274187
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1407674.2031052916
# [LightGBM] [Warning] boosting is set=dart, boosting_type=gbdt will be ignored. Current value: boosting=dart
# [LightGBM] [Warning] feature_fraction is set=0.6029094458315314, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6029094458315314
# [LightGBM] [Warning] min_data_in_leaf is set=4, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=4
# [LightGBM] [Warning] lambda_l1 is set=0, reg_alpha=0.0 will be ignored. Current value: lambda_l1=0
# [LightGBM] [Warning] bagging_fraction is set=0.6411794121413146, subsample=1.0 will be ignored. Current value: bagging_fraction=0.6411794121413146
# [LightGBM] [Warning] lambda_l2 is set=0, reg_lambda=0.0 will be ignored. Current value: lambda_l2=0
# RMSE:
# 1469227.7667077498
# 100%|██████████| 250/250 [01:21<00:00,  3.06trial/s, best loss: 1363635.3843579353]

# %%
# fit on all CA training data
lgbm_using_CA = LGBMRegressor(
    boosting='DART',
    bagging_fraction=best['bagging_fraction'], 
    feature_fraction=best['feature_fraction'],
    reg_alpha=0,
    reg_lambda=0,
    max_depth=int(best['max_depth']),
    min_child_weight=best['min_child_weight'],
    min_data_in_leaf=int(best['min_data_in_leaf']),
    n_estimators=int(best['n_estimators']),
    num_leaves=int(best['num_leaves']),
    learning_rate=best['learning_rate'],
)
lgbm_using_CA.fit(X_train_CA, y_train_CA)
r2_score(y_test_CA,lgbm_using_CA.predict(X_test_CA))
# Out:
# [LightGBM] [Warning] boosting is set=DART, boosting_type=gbdt will be ignored. Current value: boosting=DART
# [LightGBM] [Warning] feature_fraction is set=0.6956450441117951, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.6956450441117951
# [LightGBM] [Warning] min_data_in_leaf is set=5, min_child_samples=20 will be ignored. Current value: min_data_in_leaf=5
# [LightGBM] [Warning] bagging_fraction is set=0.5806355830500778, subsample=1.0 will be ignored. Current value: bagging_fraction=0.5806355830500778
# 0.5071921270247036

# %%
# save model
save_obj(lgbm_using_CA, '../models/lgbm_using_CA.pickle')
